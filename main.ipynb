# %%
from collections import defaultdict
from microtc.utils import tweet_iterator
from b4msa.textmodel import TextModel
import json
from os.path import join
from util import load_dataset
dataset_names = ['multibooked_ca_dev','multibooked_ca_train','multibooked_eu_dev','multibooked_eu_train','norec_dev','norec_train','opener_en_dev','opener_en_train','opener_es_dev','opener_es_train']


multibooked_ca_dev = load_dataset('data/multibooked_ca/dev.json')
multibooked_ca_train = load_dataset('data/multibooked_ca/train.json')

multibooked_eu_dev = load_dataset('data/multibooked_eu/dev.json')
multibooked_eu_train = load_dataset('data/multibooked_eu/train.json')

norec_dev = load_dataset('data/norec/dev.json')
norec_train = load_dataset('data/norec/train.json')

opener_en_dev = load_dataset('data/opener_en/dev.json')
opener_en_train = load_dataset('data/opener_en/train.json')

opener_es_dev = load_dataset('data/opener_es/dev.json')
opener_es_train = load_dataset('data/opener_es/train.json')

# %%
datasets = {
    "multibooked_ca_dev":multibooked_ca_dev,
    "multibooked_ca_train":multibooked_ca_train,
    "multibooked_eu_dev":multibooked_eu_dev,
    "multibooked_eu_train":multibooked_eu_train,
    "norec_dev":norec_dev,
    "norec_train":norec_train,
    "opener_en_dev":opener_en_dev,
    "opener_en_train":opener_en_train,
    "opener_es_dev":opener_es_dev,
    "opener_es_train":opener_es_train}

count=dict()

for name in datasets.keys():
    count[name]=defaultdict(int)
    for line in datasets[name]:
        for o in line['opinions']:
            count[name][o['Polarity']] +=1
            count[name][o['Intensity']] +=1

# %%
train_data=opener_en_dev+opener_en_train
tm = TextModel(lang="english", token_list=[-1],stemming=True).fit(train_data)
# Out:
# [{'sent_id': '../opener/en/kaf/hotel/english00032_30ddf6dff464d0b92c6fbae7019ece91-2',
#   'text': 'very warm welcome at the reception , very friendly and helpful personnel , especially at the bar and during breakfast , a really good experience overall , had a relaxing drink at the bar , visited the cigarrum smokers lounge and had a great start into the day at the very nicely assorted breakfast buffet .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['personnel'], ['63:72']],
#     'Polar_expression': [['helpful'], ['55:62']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['personnel'], ['63:72']],
#     'Polar_expression': [['very friendly'], ['37:50']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['experience'], ['134:144']],
#     'Polar_expression': [['really good'], ['122:133']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['welcome'], ['10:17']],
#     'Polar_expression': [['very warm'], ['0:9']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['breakfast buffet'], ['288:304']],
#     'Polar_expression': [['very nicely assorted'], ['267:287']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00200_e8f707795fc0c7f605a1f7115c3da711-1',
#   'text': 'The room is very small , about 10m2',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The room'], ['0:8']],
#     'Polar_expression': [['very small'], ['12:22']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00200_e8f707795fc0c7f605a1f7115c3da711-2',
#   'text': 'Hotel Premiere Classe Orly Rungis is near the airport and close to Orly',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Hotel Premiere Classe Orly Rungis'], ['0:33']],
#     'Polar_expression': [['near the airport'], ['37:53']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['Hotel Premiere Classe Orly Rungis'], ['0:33']],
#     'Polar_expression': [['close to Orly major highways'], ['0:71']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00200_e8f707795fc0c7f605a1f7115c3da711-3',
#   'text': 'major highways ( all night heard the noise of passing large vehicles ) .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Hotel Premiere Classe Orly Rungis'], ['0:33']],
#     'Polar_expression': [['noise of passing large vehicles'], ['37:68']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00200_e8f707795fc0c7f605a1f7115c3da711-4',
#   'text': 'Near the hotel there is a bus stop that goes to the RER station .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['a bus stop that goes to the RER station'], ['24:63']],
#     'Polar_expression': [['there is'], ['15:23']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00200_e8f707795fc0c7f605a1f7115c3da711-5',
#   'text': 'In this area there is famous Rungis market , the largest food market in the world .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Rungis market'], ['29:42']],
#     'Polar_expression': [['there is'], ['13:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00200_e8f707795fc0c7f605a1f7115c3da711-6',
#   'text': 'Transfer from the airport to the hotel we had a free ( ask about a transfer at the information desk at the airport ) .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Transfer from the airport to the hotel'], ['0:38']],
#     'Polar_expression': [['free'], ['48:52']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00200_e8f707795fc0c7f605a1f7115c3da711-7',
#   'text': 'Minibus goes from the airport to a hotel .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Minibus'], ['0:7']],
#     'Polar_expression': [['goes from the airport to a hotel'], ['8:40']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00200_e8f707795fc0c7f605a1f7115c3da711-8',
#   'text': 'Transfer from hotel to airport · 6 Euro.',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Transfer from hotel to airport'], ['0:30']],
#     'Polar_expression': [['6 Euro.'], ['33:40']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00064_5fe84dfe3d4af6e6b8ef7b2ca8ac6c8f-1',
#   'text': 'Best holidays ever !',
#   'opinions': [{'Source': [[], []],
#     'Target': [['holidays'], ['5:13']],
#     'Polar_expression': [['Best ever !'], ['0:20']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00064_5fe84dfe3d4af6e6b8ef7b2ca8ac6c8f-2',
#   'text': 'Everything was excellent .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Everything'], ['0:10']],
#     'Polar_expression': [['excellent'], ['15:24']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00064_5fe84dfe3d4af6e6b8ef7b2ca8ac6c8f-3',
#   'text': 'We enjoyed the time on the beach and the friendliness of the people working there .',
#   'opinions': [{'Source': [['We'], ['0:2']],
#     'Target': [['the friendliness'], ['37:53']],
#     'Polar_expression': [['enjoyed'], ['3:10']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [['We'], ['0:2']],
#     'Target': [['the time'], ['11:19']],
#     'Polar_expression': [['enjoyed'], ['3:10']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00064_5fe84dfe3d4af6e6b8ef7b2ca8ac6c8f-4',
#   'text': 'Fantastic food , breathtaken view from the bar .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['food'], ['10:14']],
#     'Polar_expression': [['Fantastic'], ['0:9']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['view'], ['29:33']],
#     'Polar_expression': [['breathtaken'], ['17:28']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00064_5fe84dfe3d4af6e6b8ef7b2ca8ac6c8f-5',
#   'text': 'Great music and moments that we will always remember .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['moments'], ['16:23']],
#     'Polar_expression': [['Great'], ['0:5']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['music'], ['6:11']],
#     'Polar_expression': [['Great'], ['0:5']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [['we'], ['29:31']],
#     'Target': [[], []],
#     'Polar_expression': [['will always remember'], ['32:52']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00064_5fe84dfe3d4af6e6b8ef7b2ca8ac6c8f-6',
#   'text': 'See you next year .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-1',
#   'text': 'Overnight',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-2',
#   'text': 'We stayed in this hotel as we arrived quite late in the day on out inbound flight from our summer holiday .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-3',
#   'text': 'It is situated in Frankfurt Flughaven railway station , so as one might expect transport connections are superb .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['transport connections'], ['79:100']],
#     'Polar_expression': [['superb'], ['105:111']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['It'], ['0:2']],
#     'Polar_expression': [['situated in Frankfurt Flughaven railway station'],
#      ['6:53']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-4',
#   'text': 'The check in was quick and efficient , just what you need after a long flight .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The check in'], ['0:12']],
#     'Polar_expression': [['efficient'], ['27:36']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The check in'], ['0:12']],
#     'Polar_expression': [['quick'], ['17:22']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-5',
#   'text': 'The room was adequate .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The room'], ['0:8']],
#     'Polar_expression': [['adequate'], ['13:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-6',
#   'text': 'We ordered room service .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-7',
#   'text': 'The food came quickly , was hot , tasty , and expensive , very expensive .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The food'], ['0:8']],
#     'Polar_expression': [['expensive'], ['46:55']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The food'], ['0:8']],
#     'Polar_expression': [['came quickly'], ['9:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The food'], ['0:8']],
#     'Polar_expression': [['hot'], ['28:31']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The food'], ['0:8']],
#     'Polar_expression': [['tasty'], ['34:39']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The food'], ['0:8']],
#     'Polar_expression': [['very expensive'], ['58:72']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-8',
#   'text': 'Over 40 Euros for a pizza , burger and two drinks .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['Over 40 Euros for a pizza , burger and two drinks'],
#      ['0:49']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00210_f4aa2529a7784fec56fad627916db4b7-9',
#   'text': 'However the room only cost 75 Euros for the night .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['the room'], ['8:16']],
#     'Polar_expression': [['only cost 75 Euros'], ['17:35']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00070_4b333078625224037956975e6fba0e41-1',
#   'text': "One of the cleanest Travelodges I 've been to !",
#   'opinions': [{'Source': [[], []],
#     'Target': [['Travelodges'], ['20:31']],
#     'Polar_expression': [['One of the cleanest'], ['0:19']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00070_4b333078625224037956975e6fba0e41-2',
#   'text': 'This Travelodge is well placed in the City Centre and a short walk from the station and a short walk to the shops , restaurants etc. that Leeds has to offer .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['This Travelodge'], ['0:15']],
#     'Polar_expression': [['short walk to the shops , restaurants etc.'],
#      ['90:132']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['This Travelodge'], ['0:15']],
#     'Polar_expression': [['well placed in the City Centre'], ['19:49']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['This Travelodge'], ['0:15']],
#     'Polar_expression': [['short walk from the station'], ['56:83']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00070_4b333078625224037956975e6fba0e41-3',
#   'text': "The rooms are one of the cleanest Travelodges I 've been too however the corridors and reception area is a little rough from all of the Hen / Stag weekend traffic .",
#   'opinions': [{'Source': [[], []],
#     'Target': [['reception area'], ['87:101']],
#     'Polar_expression': [['a little rough'], ['105:119']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['the corridors'], ['69:82']],
#     'Polar_expression': [['a little rough'], ['105:119']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The rooms'], ['0:9']],
#     'Polar_expression': [['one of the cleanest'], ['14:33']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00070_4b333078625224037956975e6fba0e41-4',
#   'text': "There were a few Stag weekenders checking in when we were however we didn 't experience any noise or unpleasantness that would stop us from coming back in the future for our city breaks to Leeds .",
#   'opinions': [{'Source': [['we'], ['66:68']],
#     'Target': [['any noise'], ['88:97']],
#     'Polar_expression': [["didn 't experience"], ['69:87']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [['we'], ['66:68']],
#     'Target': [['unpleasantness'], ['101:115']],
#     'Polar_expression': [["didn 't experience"], ['69:87']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00070_4b333078625224037956975e6fba0e41-5',
#   'text': 'It a good location , basic , clean and thats all I can ask for for the price .',
#   'opinions': [{'Source': [['I'], ['49:50']],
#     'Target': [['thats'], ['39:44']],
#     'Polar_expression': [['can ask for the price'], ['51:76']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['location'], ['10:18']],
#     'Polar_expression': [['good'], ['5:9']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['location'], ['10:18']],
#     'Polar_expression': [['clean'], ['29:34']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['location'], ['10:18']],
#     'Polar_expression': [['basic'], ['21:26']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00170_ce1f9b38f0bec2250f15e8b855713ffd-1',
#   'text': 'Excellent beach resort',
#   'opinions': [{'Source': [[], []],
#     'Target': [['beach resort'], ['10:22']],
#     'Polar_expression': [['Excellent'], ['0:9']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00170_ce1f9b38f0bec2250f15e8b855713ffd-2',
#   'text': 'Very large resort hotel but we were upgraded to suites on arrival , however these were an extremely long walk from the restaurant / reception approx 500 metres .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['extremely long walk from the restaurant / reception'],
#      ['90:141']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['resort hotel'], ['11:23']],
#     'Polar_expression': [['Very large'], ['0:10']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00170_ce1f9b38f0bec2250f15e8b855713ffd-3',
#   'text': 'When walking problem were presented to the General Manager Mr Y. A. we were moved to two adjacent family rooms closer to these facilities and also given the blue bands allocated to repeat visitors , he could not have been more helpful .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['he'], ['199:201']],
#     'Polar_expression': [['could not have been more helpful'], ['202:234']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00170_ce1f9b38f0bec2250f15e8b855713ffd-4',
#   'text': 'It is a shame that given such ehormous pool area there is more unheated than heated and that would be my only complaint about the actual hotel facilities .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00170_ce1f9b38f0bec2250f15e8b855713ffd-5',
#   'text': 'I would highly recommend this resort especially compared with ones in Sharm .',
#   'opinions': [{'Source': [['I'], ['0:1']],
#     'Target': [['this resort'], ['25:36']],
#     'Polar_expression': [['would highly recommend'], ['2:24']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00012_0d83dca3caeaaf8eceffcae22ebf53b6-1',
#   'text': 'Tip top · top tip !',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00012_0d83dca3caeaaf8eceffcae22ebf53b6-2',
#   'text': "I have to say that I 've had a very nice holiday in this hotel .",
#   'opinions': [{'Source': [[], []],
#     'Target': [['holiday'], ['41:48']],
#     'Polar_expression': [['very nice'], ['31:40']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00012_0d83dca3caeaaf8eceffcae22ebf53b6-3',
#   'text': 'Everybody was very kind and friendly .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Everybody'], ['0:9']],
#     'Polar_expression': [['very kind'], ['14:23']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['Everybody'], ['0:9']],
#     'Polar_expression': [['friendly'], ['28:36']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00012_0d83dca3caeaaf8eceffcae22ebf53b6-4',
#   'text': 'Especially the team of the main restaurant was really professionell and nice .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['the team of the main restaurant'], ['11:42']],
#     'Polar_expression': [['nice'], ['72:76']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['the team of the main restaurant'], ['11:42']],
#     'Polar_expression': [['really professionell'], ['47:67']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00012_0d83dca3caeaaf8eceffcae22ebf53b6-5',
#   'text': 'I felt like a princess , sometimes ; · ) !',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00012_0d83dca3caeaaf8eceffcae22ebf53b6-6',
#   'text': 'Thank you very much everybody !',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00012_0d83dca3caeaaf8eceffcae22ebf53b6-7',
#   'text': 'I will come back there .',
#   'opinions': [{'Source': [['I'], ['0:1']],
#     'Target': [['there'], ['17:22']],
#     'Polar_expression': [['will come back'], ['2:16']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00110_7a012157f787f3c49871371b3f64b382-1',
#   'text': 'Business and shopping',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00110_7a012157f787f3c49871371b3f64b382-2',
#   'text': 'Very warm comfortable friendly hotel .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['hotel'], ['31:36']],
#     'Polar_expression': [['comfortable'], ['10:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['hotel'], ['31:36']],
#     'Polar_expression': [['Very warm'], ['0:9']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['hotel'], ['31:36']],
#     'Polar_expression': [['friendly'], ['22:30']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00110_7a012157f787f3c49871371b3f64b382-3',
#   'text': 'Near Milano Centrale train station with bus stop to all airports .',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['with bus stop to all airports'], ['35:64']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['Near Milano Centrale train station'], ['0:34']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00110_7a012157f787f3c49871371b3f64b382-4',
#   'text': 'It takes 20 min. to get to Corso Buenos Aires where you can find very nice shops .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00110_7a012157f787f3c49871371b3f64b382-5',
#   'text': 'At the hotel : rooms are not big , but nice and clean ( I was at this hotel several times and saw different rooms ) , clean comfortable bathrooms .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['rooms'], ['15:20']],
#     'Polar_expression': [['not big'], ['25:32']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['rooms'], ['15:20']],
#     'Polar_expression': [['clean'], ['48:53']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['rooms'], ['15:20']],
#     'Polar_expression': [['nice'], ['39:43']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['bathrooms'], ['136:145']],
#     'Polar_expression': [['comfortable'], ['124:135']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['bathrooms'], ['136:145']],
#     'Polar_expression': [['clean'], ['118:123']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00110_7a012157f787f3c49871371b3f64b382-6',
#   'text': 'I prefer stay at this hotel , when they have free rooms .',
#   'opinions': [{'Source': [['I'], ['0:1']],
#     'Target': [['stay at this hotel'], ['9:27']],
#     'Polar_expression': [['prefer'], ['2:8']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00051_496c24f962c80bf3bb9efff898020602-1',
#   'text': 'Cheap , but miserable',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['Cheap'], ['0:5']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['miserable'], ['12:21']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00051_496c24f962c80bf3bb9efff898020602-2',
#   'text': 'I requested a non · smoking room , only to find a cigarette in the toilet .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['a cigarette'], ['48:59']],
#     'Polar_expression': [['find in the toilet'], ['43:73']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00051_496c24f962c80bf3bb9efff898020602-3',
#   'text': 'After calling reception , they offered me an upgrade .',
#   'opinions': [{'Source': [['me'], ['39:41']],
#     'Target': [['an upgrade'], ['42:52']],
#     'Polar_expression': [['offered'], ['31:38']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00051_496c24f962c80bf3bb9efff898020602-4',
#   'text': 'This however requires walking all around the hotel , and there is only one set of elevators for each floor ( the hotel is a pyramid , and the elevators are only in one corner ) .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['set of elevators'], ['75:91']],
#     'Polar_expression': [['there is only one'], ['57:74']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['the hotel'], ['109:118']],
#     'Polar_expression': [['a pyramid'], ['122:131']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['This'], ['0:4']],
#     'Polar_expression': [['requires walking all around the hotel'], ['13:50']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['the elevators'], ['138:151']],
#     'Polar_expression': [['only in one corner'], ['156:174']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00051_496c24f962c80bf3bb9efff898020602-5',
#   'text': 'The food was expensive .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The food'], ['0:8']],
#     'Polar_expression': [['expensive'], ['13:22']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00051_496c24f962c80bf3bb9efff898020602-6',
#   'text': 'And my salad was a dressing soup topped with some lettuce .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00071_6901a988b452abe791e088abe8e7dd83-1',
#   'text': 'Location of the hotel and dinner excellent',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Location'], ['0:8']],
#     'Polar_expression': [['excellent'], ['33:42']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['dinner'], ['26:32']],
#     'Polar_expression': [['excellent'], ['33:42']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00071_6901a988b452abe791e088abe8e7dd83-2',
#   'text': '· small rooms but a big balcony in rooms with seasight',
#   'opinions': [{'Source': [[], []],
#     'Target': [['rooms'], ['8:13']],
#     'Polar_expression': [['small'], ['2:7']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['balcony'], ['24:31']],
#     'Polar_expression': [['big'], ['20:23']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['balcony'], ['24:31']],
#     'Polar_expression': [['with seasight'], ['41:54']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00071_6901a988b452abe791e088abe8e7dd83-3',
#   'text': '· breakfeast ( buffet ) is good , dinner is excellent',
#   'opinions': [{'Source': [[], []],
#     'Target': [['dinner'], ['34:40']],
#     'Polar_expression': [['excellent'], ['44:53']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['breakfeast'], ['2:12']],
#     'Polar_expression': [['good'], ['27:31']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00071_6901a988b452abe791e088abe8e7dd83-4',
#   'text': '· bathroom small , but clean',
#   'opinions': [{'Source': [[], []],
#     'Target': [['bathroom'], ['2:10']],
#     'Polar_expression': [['small'], ['11:16']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['bathroom'], ['2:10']],
#     'Polar_expression': [['clean'], ['23:28']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00071_6901a988b452abe791e088abe8e7dd83-5',
#   'text': '· matras familyroom was hard and bad in the single room',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00071_6901a988b452abe791e088abe8e7dd83-6',
#   'text': '· Dutch ; 42 , 66 and 67 years',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00071_6901a988b452abe791e088abe8e7dd83-7',
#   'text': '· wifi is free',
#   'opinions': [{'Source': [[], []],
#     'Target': [['wifi'], ['2:6']],
#     'Polar_expression': [['free'], ['10:14']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00122_b509ee1b998f3418b1fd4a8096880441-1',
#   'text': 'Stay was too short',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Stay'], ['0:4']],
#     'Polar_expression': [['too short'], ['9:18']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00122_b509ee1b998f3418b1fd4a8096880441-2',
#   'text': 'I stayed at the hotel for only 2 nights .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00122_b509ee1b998f3418b1fd4a8096880441-3',
#   'text': 'The staff was exceptionally friendly and helpful .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The staff'], ['0:9']],
#     'Polar_expression': [['exceptionally friendly'], ['14:36']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['The staff'], ['0:9']],
#     'Polar_expression': [['helpful'], ['41:48']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00122_b509ee1b998f3418b1fd4a8096880441-4',
#   'text': 'Breakfast was perfect with a nice variety .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Breakfast'], ['0:9']],
#     'Polar_expression': [['perfect'], ['14:21']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['variety'], ['34:41']],
#     'Polar_expression': [['nice'], ['29:33']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00122_b509ee1b998f3418b1fd4a8096880441-5',
#   'text': 'Hope to return to the area soon and will definently try and stay here again .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['here'], ['65:69']],
#     'Polar_expression': [['stay again'], ['60:75']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['here'], ['65:69']],
#     'Polar_expression': [['definently try'], ['41:55']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00118_aea36867626915cb3f94bc7c17ec5bb9-1',
#   'text': 'Steigenberger Airport Hotel Frankfurt',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00118_aea36867626915cb3f94bc7c17ec5bb9-2',
#   'text': 'The staff is very friendly , prompt and courteous .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The staff'], ['0:9']],
#     'Polar_expression': [['prompt'], ['29:35']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The staff'], ['0:9']],
#     'Polar_expression': [['courteous'], ['40:49']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The staff'], ['0:9']],
#     'Polar_expression': [['very friendly'], ['13:26']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00118_aea36867626915cb3f94bc7c17ec5bb9-3',
#   'text': 'Check · in / Check · out was a piece of cake .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Check · in / Check · out'], ['0:24']],
#     'Polar_expression': [['a piece of cake'], ['29:44']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00118_aea36867626915cb3f94bc7c17ec5bb9-4',
#   'text': 'I got an upgrade to Executive suite at no cost .',
#   'opinions': [{'Source': [['I'], ['0:1']],
#     'Target': [['an upgrade to Executive suite'], ['6:35']],
#     'Polar_expression': [['got'], ['2:5']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [['I'], ['0:1']],
#     'Target': [['an upgrade to Executive suite'], ['6:35']],
#     'Polar_expression': [['at no cost'], ['36:46']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00118_aea36867626915cb3f94bc7c17ec5bb9-5',
#   'text': 'Outbeaten cleanliness noticed from lobby to room .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['cleanliness'], ['10:21']],
#     'Polar_expression': [['Outbeaten'], ['0:9']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00118_aea36867626915cb3f94bc7c17ec5bb9-6',
#   'text': 'I was impressed with the breakfast selection .',
#   'opinions': [{'Source': [['I'], ['0:1']],
#     'Target': [['breakfast selection'], ['25:44']],
#     'Polar_expression': [['was impressed'], ['2:15']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00180_d5ec496d5858acfbab77283dd350b0ec-1',
#   'text': 'Great place , friendly and efficient staff',
#   'opinions': [{'Source': [[], []],
#     'Target': [['place'], ['6:11']],
#     'Polar_expression': [['Great'], ['0:5']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['staff'], ['37:42']],
#     'Polar_expression': [['friendly'], ['14:22']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['staff'], ['37:42']],
#     'Polar_expression': [['efficient'], ['27:36']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00180_d5ec496d5858acfbab77283dd350b0ec-2',
#   'text': 'stayed for a weekend , good location between village and beach , accepts dogs · a must for us , great staff , very helpful',
#   'opinions': [{'Source': [[], []],
#     'Target': [['location'], ['28:36']],
#     'Polar_expression': [['good'], ['23:27']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['staff'], ['102:107']],
#     'Polar_expression': [['very helpful'], ['110:122']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['staff'], ['102:107']],
#     'Polar_expression': [['great'], ['96:101']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['dogs'], ['73:77']],
#     'Polar_expression': [['accepts'], ['65:72']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00180_d5ec496d5858acfbab77283dd350b0ec-3',
#   'text': "the car park gets a little busy when there is a function on , but all worked out with a bit of cooperation ; the breakfast times are fine during the week but I would have preferred a little later cut off on Sunday · again the staff sorted it to everýone 's satisfaction .",
#   'opinions': [{'Source': [[], []],
#     'Target': [['the car park'], ['0:12']],
#     'Polar_expression': [['a little busy'], ['18:31']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['it'], ['239:241']],
#     'Polar_expression': [["sorted to everýone 's satisfaction"], ['232:269']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [['I'], ['158:159']],
#     'Target': [['a little later cut off on Sunday'], ['181:213']],
#     'Polar_expression': [['would have preferred'], ['160:180']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['the breakfast times'], ['109:128']],
#     'Polar_expression': [['fine'], ['133:137']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00180_d5ec496d5858acfbab77283dd350b0ec-4',
#   'text': 'We had a groundfloor room so access for my scootmobile was no problem and parking of the scootmobile was also sorted without any fuss · a great team , staff and management .',
#   'opinions': [{'Source': [['We'], ['0:2']],
#     'Target': [['groundfloor room'], ['9:25']],
#     'Polar_expression': [['no problem'], ['59:69']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [['We'], ['0:2']],
#     'Target': [['access for my scootmobile'], ['29:54']],
#     'Polar_expression': [['no problem'], ['59:69']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['management'], ['161:171']],
#     'Polar_expression': [['great'], ['138:143']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['team'], ['144:148']],
#     'Polar_expression': [['great'], ['138:143']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['staff'], ['151:156']],
#     'Polar_expression': [['great'], ['138:143']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['parking of the scootmobile'], ['74:100']],
#     'Polar_expression': [['sorted without any fuss'], ['110:133']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00016_1bf091a4517b245ddc05ed2efd135973-1',
#   'text': 'Very nice hotel !',
#   'opinions': [{'Source': [[], []],
#     'Target': [['hotel'], ['10:15']],
#     'Polar_expression': [['Very nice !'], ['0:17']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00016_1bf091a4517b245ddc05ed2efd135973-2',
#   'text': "The hotel was very nice , I think it 's good that they have like 5 restaurants so the people are spread over 5 restaurants so it 's never so crowded .",
#   'opinions': [{'Source': [[], []],
#     'Target': [['the people'], ['82:92']],
#     'Polar_expression': [['spread over 5 restaurants'], ['97:122']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['it'], ['126:128']],
#     'Polar_expression': [['never so crowded'], ['132:148']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The hotel'], ['0:9']],
#     'Polar_expression': [['very nice'], ['14:23']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['5 restaurants'], ['65:78']],
#     'Polar_expression': [['have'], ['55:59']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00016_1bf091a4517b245ddc05ed2efd135973-3',
#   'text': "But on the other hand I missed the a la carte restaurants that you have in so many hotels because that 's more pleasant / cosy .",
#   'opinions': [{'Source': [['I'], ['22:23']],
#     'Target': [['the a la carte restaurants'], ['31:57']],
#     'Polar_expression': [['missed'], ['24:30']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['that'], ['98:102']],
#     'Polar_expression': [['cosy'], ['122:126']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['that'], ['98:102']],
#     'Polar_expression': [['more pleasant'], ['106:119']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00016_1bf091a4517b245ddc05ed2efd135973-4',
#   'text': 'The hotel is very clean !',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The hotel'], ['0:9']],
#     'Polar_expression': [['very clean !'], ['13:25']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00016_1bf091a4517b245ddc05ed2efd135973-5',
#   'text': 'The food was very good , I especially liked the breakfast because there were a lot of different kinds of cheese , and for dinner the Asian restaurant is my favorite .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['cheese'], ['105:111']],
#     'Polar_expression': [['there were a lot of different kinds of'],
#      ['66:104']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['The food'], ['0:8']],
#     'Polar_expression': [['very good'], ['13:22']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00016_1bf091a4517b245ddc05ed2efd135973-6',
#   'text': 'There are mainly German people in the hotel ( I think 70 / 80 percent )',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00016_1bf091a4517b245ddc05ed2efd135973-7',
#   'text': "But what I really didn 't like was the music in the lobby bar en all the other bars , way to old !",
#   'opinions': [{'Source': [['I'], ['9:10']],
#     'Target': [['the music'], ['35:44']],
#     'Polar_expression': [["really didn 't like"], ['11:30']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00016_1bf091a4517b245ddc05ed2efd135973-8',
#   'text': 'I hope that next time thay have an area with modern music',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00072_4cc2e9801df78f120125f41eac84ee35-1',
#   'text': 'Le Méridien Munich',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00072_4cc2e9801df78f120125f41eac84ee35-2',
#   'text': 'We have stayed in this hotel for 4 nights recently .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00072_4cc2e9801df78f120125f41eac84ee35-3',
#   'text': 'Our room was a city view room facing Street .. So from a view perspective , there is nothing that we can wow about !!!',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Our room'], ['0:8']],
#     'Polar_expression': [['city view facing Street'], ['15:43']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [['we'], ['98:100']],
#     'Target': [['wow about'], ['105:114']],
#     'Polar_expression': [['there is nothing'], ['76:92']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00072_4cc2e9801df78f120125f41eac84ee35-4',
#   'text': 'The decor of the hotel is very old just another 3 star hotel standard !!!',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The decor'], ['0:9']],
#     'Polar_expression': [['very old'], ['26:34']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['hotel'], ['55:60']],
#     'Polar_expression': [['3 star standard !!!'], ['48:73']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00072_4cc2e9801df78f120125f41eac84ee35-5',
#   'text': 'Nothing special !!!',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['Nothing special !!!'], ['0:19']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00072_4cc2e9801df78f120125f41eac84ee35-6',
#   'text': 'The room does have a LCD TV , i will not stay in this Hotel Again .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['LCD TV'], ['21:27']],
#     'Polar_expression': [['have'], ['14:18']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [['i'], ['30:31']],
#     'Target': [['this Hotel'], ['49:59']],
#     'Polar_expression': [['will not stay in Again'], ['32:65']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-1',
#   'text': 'Expensive airport hotel',
#   'opinions': [{'Source': [[], []],
#     'Target': [['airport hotel'], ['10:23']],
#     'Polar_expression': [['Expensive'], ['0:9']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-2',
#   'text': 'Basic Sheraton below my expectations .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Sheraton'], ['6:14']],
#     'Polar_expression': [['Basic'], ['0:5']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['Sheraton'], ['6:14']],
#     'Polar_expression': [['below my expectations'], ['15:36']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-3',
#   'text': 'Free shuttle bus to / from the airport .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['shuttle bus to / from the airport'], ['5:38']],
#     'Polar_expression': [['Free'], ['0:4']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-4',
#   'text': 'Bell staff very good and helpfull .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Bell staff'], ['0:10']],
#     'Polar_expression': [['helpfull'], ['25:33']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['Bell staff'], ['0:10']],
#     'Polar_expression': [['very good'], ['11:20']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-5',
#   'text': "Rooms recently refurbished but not in acordance of today 's traveller",
#   'opinions': [{'Source': [[], []],
#     'Target': [['Rooms'], ['0:5']],
#     'Polar_expression': [['recently refurbished'], ['6:26']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['Rooms'], ['0:5']],
#     'Polar_expression': [["not in acordance of today 's traveller"],
#      ['31:69']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-6',
#   'text': 'Some staff does not speak any English at all !!',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Some staff'], ['0:10']],
#     'Polar_expression': [['does not speak any English at all !!'], ['11:47']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-7',
#   'text': 'Pool area dated',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Pool area'], ['0:9']],
#     'Polar_expression': [['dated'], ['10:15']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-8',
#   'text': 'Lounge very poor .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Lounge'], ['0:6']],
#     'Polar_expression': [['very poor'], ['7:16']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-9',
#   'text': 'After breakfast no meals or drinks offered .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['drinks'], ['28:34']],
#     'Polar_expression': [['After breakfast no offered'], ['0:42']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['meals'], ['19:24']],
#     'Polar_expression': [['After breakfast no offered'], ['0:42']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-10',
#   'text': 'Dirty dishes , no fruit , empty firdge , loud TV',
#   'opinions': [{'Source': [[], []],
#     'Target': [['TV'], ['46:48']],
#     'Polar_expression': [['loud'], ['41:45']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['dishes'], ['6:12']],
#     'Polar_expression': [['Dirty'], ['0:5']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['fruit'], ['18:23']],
#     'Polar_expression': [['no'], ['15:17']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['firdge'], ['32:38']],
#     'Polar_expression': [['empty'], ['26:31']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00225_ffb11fd9fc93b3b74cde6a9dcb91be15-11',
#   'text': 'Would expect much more for the price paid ( 160 USD / night )',
#   'opinions': [{'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['Would expect much more'], ['0:22']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00015_18a9f5b73a668f8d4b7c7e3fe6bf039a-1',
#   'text': 'Good times , great people',
#   'opinions': [{'Source': [[], []],
#     'Target': [['people'], ['19:25']],
#     'Polar_expression': [['great'], ['13:18']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['times'], ['5:10']],
#     'Polar_expression': [['Good'], ['0:4']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00015_18a9f5b73a668f8d4b7c7e3fe6bf039a-2',
#   'text': 'We had a great time.The staff were great the food was great.And there is lots of private areas by the sea.What can i say.Love the Grand Palladium jamaica.And we hope to see all the staff next year .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['staff'], ['24:29']],
# ...
#   'text': 'It only was a pity that the underground parking did cost us exact 50 % of the room rate .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['the underground parking'], ['24:47']],
#     'Polar_expression': [['cost exact 50 % of the room rate'], ['52:87']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00065_60ef16c15790a198184bfd267b7d9c76-6',
#   'text': 'But the rooms were indeed very comfortable and the food excellent !',
#   'opinions': [{'Source': [[], []],
#     'Target': [['the rooms'], ['4:13']],
#     'Polar_expression': [['very comfortable'], ['26:42']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['the food'], ['47:55']],
#     'Polar_expression': [['excellent !'], ['56:67']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00010_111141faf5317cc30895165ff77fa44e-1',
#   'text': 'Club dolphin',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00010_111141faf5317cc30895165ff77fa44e-2',
#   'text': 'clean but not updated is same as it was 9years ago , not to many rooms just enough to make it not too crowded , we were full board breakfast was good , rest of meals not enough choice .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['it'], ['33:35']],
#     'Polar_expression': [['same as 9years ago'], ['25:50']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['clean'], ['0:5']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [[], []],
#     'Polar_expression': [['not updated'], ['10:21']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['breakfast'], ['131:140']],
#     'Polar_expression': [['good'], ['145:149']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['rooms'], ['65:70']],
#     'Polar_expression': [['not to many'], ['53:64']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['rest of meals'], ['152:165']],
#     'Polar_expression': [['not enough choice'], ['166:183']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-1',
#   'text': 'Central location',
#   'opinions': [{'Source': [[], []],
#     'Target': [['location'], ['8:16']],
#     'Polar_expression': [['Central'], ['0:7']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-2',
#   'text': 'Good location , 2 minutes from Duomo , but very loud location , not possible to have a quite night sleep at all .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['location'], ['53:61']],
#     'Polar_expression': [['not possible to have a quite night sleep at all'],
#      ['64:111']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['location'], ['53:61']],
#     'Polar_expression': [['very loud'], ['43:52']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['location'], ['5:13']],
#     'Polar_expression': [['Good'], ['0:4']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['location'], ['5:13']],
#     'Polar_expression': [['2 minutes from Duomo'], ['16:36']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-3',
#   'text': 'Very small rooms , old furnished .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['rooms'], ['11:16']],
#     'Polar_expression': [['old furnished'], ['19:32']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['rooms'], ['11:16']],
#     'Polar_expression': [['Very small'], ['0:10']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-4',
#   'text': 'Frankly only to recommend for young students who do not need sleep in the night and need a good location for little money !',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-5',
#   'text': 'Not a comfortable hotel at all .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['hotel'], ['18:23']],
#     'Polar_expression': [['Not a comfortable at all'], ['0:30']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-6',
#   'text': 'The rooms are not worth its price even for 50 euro a night .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The rooms'], ['0:9']],
#     'Polar_expression': [['not worth'], ['14:23']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['its price'], ['24:33']],
#     'Polar_expression': [['50 euro a night'], ['43:58']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-7',
#   'text': 'Breakfast is no go , but there are enough good locations everywhere to have a good coffee and snack in the morning .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Breakfast'], ['0:9']],
#     'Polar_expression': [['no go'], ['13:18']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['enough locations'], ['35:56']],
#     'Polar_expression': [['good'], ['42:46']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['enough locations'], ['35:56']],
#     'Polar_expression': [['there are'], ['25:34']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-8',
#   'text': 'Upper rooms were very small without own bathrooms and WC .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Upper rooms'], ['0:11']],
#     'Polar_expression': [['without own bathrooms and WC'], ['28:56']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['Upper rooms'], ['0:11']],
#     'Polar_expression': [['very small'], ['17:27']],
#     'Polarity': 'Negative',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-9',
#   'text': 'So , it is not really a hotel , but low budget room accommodation .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['it'], ['5:7']],
#     'Polar_expression': [['low budget room accommodation'], ['36:65']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['it'], ['5:7']],
#     'Polar_expression': [['not really a hotel'], ['11:29']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-10',
#   'text': 'I wil not recommend anyone to stay there .',
#   'opinions': [{'Source': [['I'], ['0:1']],
#     'Target': [['there'], ['35:40']],
#     'Polar_expression': [['not recommend'], ['6:19']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00069_4a24f9e92c2bd08de2cf29567b4464ab-11',
#   'text': 'Sorry : · )',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00013_14591f42d565500798a36c93ae9436aa-1',
#   'text': 'Excellent 5 star hotel',
#   'opinions': [{'Source': [[], []],
#     'Target': [['5 star hotel'], ['10:22']],
#     'Polar_expression': [['Excellent'], ['0:9']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00013_14591f42d565500798a36c93ae9436aa-2',
#   'text': '5 star hotel with easy access and good location to Frankfurt airport .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['access'], ['23:29']],
#     'Polar_expression': [['easy'], ['18:22']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['location'], ['39:47']],
#     'Polar_expression': [['good'], ['34:38']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00013_14591f42d565500798a36c93ae9436aa-3',
#   'text': 'Good shuttle bus service to and from hotel to Frankfurt airport .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['shuttle bus service'], ['5:24']],
#     'Polar_expression': [['Good'], ['0:4']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00013_14591f42d565500798a36c93ae9436aa-4',
#   'text': 'Gym and swimming pool are where I can work out my body after a long and tedious travel in the city .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Gym'], ['0:3']],
#     'Polar_expression': [['are'], ['22:25']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['swimming pool'], ['8:21']],
#     'Polar_expression': [['are'], ['22:25']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00082_7752a35e07ce26cba8b991bed66406cd-1',
#   'text': 'Friendly , helpful hosts',
#   'opinions': [{'Source': [[], []],
#     'Target': [['hosts'], ['19:24']],
#     'Polar_expression': [['Friendly'], ['0:8']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['hosts'], ['19:24']],
#     'Polar_expression': [['helpful'], ['11:18']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00082_7752a35e07ce26cba8b991bed66406cd-2',
#   'text': 'Our hosts were friendly and very helpful .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Our hosts'], ['0:9']],
#     'Polar_expression': [['friendly'], ['15:23']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['Our hosts'], ['0:9']],
#     'Polar_expression': [['very helpful'], ['28:40']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00082_7752a35e07ce26cba8b991bed66406cd-3',
#   'text': 'Everything was wonderfully clean and the en · suite bathroom was ingeniously placed .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['Everything'], ['0:10']],
#     'Polar_expression': [['wonderfully clean'], ['15:32']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['the en · suite bathroom'], ['37:60']],
#     'Polar_expression': [['ingeniously placed'], ['65:83']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00082_7752a35e07ce26cba8b991bed66406cd-4',
#   'text': 'A wonderful range of food for breakfast and we were offered scrambled egg on toast · after 3 weeks in france on bread and jam this was a feast to behold .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['range of food'], ['12:25']],
#     'Polar_expression': [['wonderful'], ['2:11']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [['we'], ['44:46']],
#     'Target': [['scrambled egg on toast'], ['60:82']],
#     'Polar_expression': [['offered'], ['52:59']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00082_7752a35e07ce26cba8b991bed66406cd-5',
#   'text': 'On Sunday morning we saw the ladies going to church in traditional dress which was wonderful to see .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00096_8884de13ff3ce43675ea8281f0e6f5c3-1',
#   'text': 'Best hotel in Hurghada',
#   'opinions': [{'Source': [[], []],
#     'Target': [['hotel'], ['5:10']],
#     'Polar_expression': [['Best'], ['0:4']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00096_8884de13ff3ce43675ea8281f0e6f5c3-2',
#   'text': 'first class service in every department from cleaners to waiters and service desk at reception , booked a double room with wife and grandaughter and was given a free upgrade to a junior suite , what more can i say excellent food and drinks plenty sunbeds at pools and beach',
#   'opinions': [{'Source': [[], []],
#     'Target': [['sunbeds'], ['247:254']],
#     'Polar_expression': [['plenty'], ['240:246']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['food'], ['224:228']],
#     'Polar_expression': [['excellent'], ['214:223']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['drinks'], ['233:239']],
#     'Polar_expression': [['excellent'], ['214:223']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['service'], ['12:19']],
#     'Polar_expression': [['first class'], ['0:11']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00080_749e7f78949835ec51256019a03818a5-1',
#   'text': 'My favourite hotel in Cologne',
#   'opinions': [{'Source': [[], []],
#     'Target': [['hotel'], ['13:18']],
#     'Polar_expression': [['My favourite'], ['0:12']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00080_749e7f78949835ec51256019a03818a5-2',
#   'text': 'excellent value for money , good breakfast and excellent wellness facilities .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['breakfast'], ['33:42']],
#     'Polar_expression': [['good'], ['28:32']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['wellness facilities'], ['57:76']],
#     'Polar_expression': [['excellent'], ['47:56']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'},
#    {'Source': [[], []],
#     'Target': [['value for money'], ['10:25']],
#     'Polar_expression': [['excellent'], ['0:9']],
#     'Polarity': 'Positive',
#     'Intensity': 'Strong'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00080_749e7f78949835ec51256019a03818a5-3',
#   'text': 'Though not in the centre the public transport system stops right in front of the hotel and brings u in a minimum of time to the centre thus avoiding parking problems and the like .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['the centre'], ['14:24']],
#     'Polar_expression': [['not in'], ['7:13']],
#     'Polarity': 'Negative',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['the public transport system'], ['25:52']],
#     'Polar_expression': [['stops right in front'], ['53:73']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'},
#    {'Source': [[], []],
#     'Target': [['parking problems'], ['149:165']],
#     'Polar_expression': [['avoiding'], ['140:148']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00080_749e7f78949835ec51256019a03818a5-4',
#   'text': 'Have been a frequent visitor to this hotel since 2000',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00062_40a2ae7cfbde5d8abdb052d58035f957-1',
#   'text': 'Budget stay in Paris',
#   'opinions': [{'Source': [[], []],
#     'Target': [['stay'], ['7:11']],
#     'Polar_expression': [['Budget'], ['0:6']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  {'sent_id': '../opener/en/kaf/hotel/english00062_40a2ae7cfbde5d8abdb052d58035f957-2',
#   'text': 'I suppose you get what you pay for .',
#   'opinions': []},
#  {'sent_id': '../opener/en/kaf/hotel/english00062_40a2ae7cfbde5d8abdb052d58035f957-3',
#   'text': 'The breakfast was decent enough .',
#   'opinions': [{'Source': [[], []],
#     'Target': [['The breakfast'], ['0:13']],
#     'Polar_expression': [['decent enough'], ['18:31']],
#     'Polarity': 'Positive',
#     'Intensity': 'Standard'}]},
#  ...]

# %%
# Out:
# {'sent_id': 'corpora/ca/carpe-diem-cadaques403-1',
#  'text': 'Tot excel·lent .',
#  'opinions': [{'Source': [[], []],
#    'Target': [['Tot'], ['0:3']],
#    'Polar_expression': [['excel·lent'], ['4:14']],
#    'Polarity': 'Positive',
#    'Intensity': 'Strong'}]}
